# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_marketing_performance.csv")   #marketing performance
df2=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_products.csv")               #products
df3=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_inventoryNew.csv")           #inventory new
df4=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_inventory.csv")              #inventory old
df5=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_order_items.csv")            #order items  
df6=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_orders.csv")                 #orders 
df7=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_customer_feedback.csv")      #customer feedback 
df8=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_customers.csv")              #customers
df9=pd.read_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_delivery_performance.csv")   #delivery performance

# %%
df6.head()
# Out:
#      order_id  customer_id           order_date promised_delivery_time  \
# 0  1961864118     30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1  1549769649      9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2  9185164487     45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3  9644738826     88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4  5427684290     83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
#
#   actual_delivery_time delivery_status  order_total payment_method  \
# 0  2024-07-17 08:47:01         On Time      3197.07           Cash
# 1  2024-05-28 13:27:29         On Time       976.55           Cash
# 2  2024-09-23 13:29:12         On Time       839.05            UPI
# 3  2023-11-24 16:33:56         On Time       440.23           Card
# 4  2023-11-20 05:18:39         On Time      2526.68           Cash
#
#    delivery_partner_id  store_id
# 0                63230      4771
# 1                14983      7534
# ...

# %%
df6.shape
# Out:
# (5000, 10)

# %%
df5.shape
# Out:
# (5000, 4)

# %%
df5.head()
# Out:
#      order_id  product_id  quantity  unit_price
# 0  1961864118      642612         3      517.03
# 1  1549769649      378676         1      881.42
# 2  9185164487      741341         2      923.84
# 3  9644738826      561860         1      874.78
# 4  5427684290      602241         2      976.55

# %%
df5.isnull().sum()
# Out:
# order_id      0
# product_id    0
# quantity      0
# unit_price    0
# dtype: int64

# %%
order=pd.merge(df5,df6,on="order_id",how="inner")

# %%
order.to_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\merged_order_items_orders.csv",index=False)

# %%
order.head()
# Out:
#      order_id  product_id  quantity  unit_price  customer_id  \
# 0  1961864118      642612         3      517.03     30065862
# 1  1549769649      378676         1      881.42      9573071
# 2  9185164487      741341         2      923.84     45477575
# 3  9644738826      561860         1      874.78     88067569
# 4  5427684290      602241         2      976.55     83298567
#
#             order_date promised_delivery_time actual_delivery_time  \
# 0  2024-07-17 08:34:01    2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  2024-05-28 13:14:29    2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  2024-09-23 13:07:12    2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  2023-11-24 16:16:56    2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  2023-11-20 05:00:39    2023-11-20 05:17:39  2023-11-20 05:18:39
#
#   delivery_status  order_total payment_method  delivery_partner_id  store_id
# 0         On Time      3197.07           Cash                63230      4771
# ...

# %%
df8.head()
# Out:
#    customer_id  customer_name                     email         phone  \
# 0     97475543  Niharika Nagi    ektataneja@example.org  912987579691
# 1     22077605   Megha Sachar      vedant45@example.com  915123179717
# 2     47822591     Hema Bahri     samiazaan@example.com  910034076149
# 3     79726146     Zaitra Vig     ishanvi87@example.org  916264232390
# 4     57102800   Januja Verma  atideshpande@example.org  917293526596
#
#                                address          area  pincode  \
# 0  23, Nayar Path, Bihar Sharif-154625         Udupi   321865
# 1  51/302, Buch Chowk\nSrinagar-570271       Aligarh   149394
# 2   941\nAnne Street, Darbhanga 186125     Begusarai   621411
# 3       43/94, Ghosh, Alappuzha 635655     Kozhikode   826054
# 4             06\nOm, Ambarnath 477463  Ichalkaranji   730539
#
#   registration_date customer_segment  total_orders  avg_order_value
# 0        2023-05-13          Premium            13           451.92
# ...

# %%
new=pd.merge(df7,df8,on="customer_id",how="left")
new.head()
# Out:
#    feedback_id    order_id  customer_id  rating  \
# 0      2234710  1961864118     30065862       4
# 1      5450964  1549769649      9573071       3
# 2       482108  9185164487     45477575       3
# 3      4823104  9644738826     88067569       4
# 4      3537464  5427684290     83298567       3
#
#                           feedback_text feedback_category sentiment  \
# 0         It was okay, nothing special.          Delivery   Neutral
# 1              The order was incorrect.    App Experience  Negative
# 2         It was okay, nothing special.    App Experience   Neutral
# 3      The product met my expectations.    App Experience   Neutral
# 4  Product was damaged during delivery.          Delivery  Negative
#
#   feedback_date     customer_name                     email         phone  \
# 0    2024-07-17   Urishilla Hegde          ydeo@example.org  910400446367
# 1    2024-05-28     Ranveer Mahal        phegde@example.org  912292591574
# ...

# %%
new.order_id.duplicated().sum()
# Out:
# np.int64(0)

# %%
new.to_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\merged_customer_feedback.csv",index=False)

# %%
df8.shape
# Out:
# (2500, 11)

# %%
df7.head()
# Out:
#    feedback_id    order_id  customer_id  rating  \
# 0      2234710  1961864118     30065862       4
# 1      5450964  1549769649      9573071       3
# 2       482108  9185164487     45477575       3
# 3      4823104  9644738826     88067569       4
# 4      3537464  5427684290     83298567       3
#
#                           feedback_text feedback_category sentiment  \
# 0         It was okay, nothing special.          Delivery   Neutral
# 1              The order was incorrect.    App Experience  Negative
# 2         It was okay, nothing special.    App Experience   Neutral
# 3      The product met my expectations.    App Experience   Neutral
# 4  Product was damaged during delivery.          Delivery  Negative
#
#   feedback_date
# 0    2024-07-17
# 1    2024-05-28
# 2    2024-09-23
# 3    2023-11-24
# 4    2023-11-20

# %%
df7.shape
# Out:
# (5000, 8)

# %%
df7.isnull().sum()
# Out:
# feedback_id          0
# order_id             0
# customer_id          0
# rating               0
# feedback_text        0
# feedback_category    0
# sentiment            0
# feedback_date        0
# dtype: int64

# %%
df9.head()
# Out:
#      order_id  delivery_partner_id        promised_time          actual_time  \
# 0  1961864118                63230  2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  1549769649                14983  2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  9185164487                39859  2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  9644738826                61497  2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  5427684290                84315  2023-11-20 05:17:39  2023-11-20 05:18:39
#
#    delivery_time_minutes  distance_km delivery_status reasons_if_delayed
# 0                   -5.0         0.96         On Time                NaN
# 1                    2.0         0.98         On Time            Traffic
# 2                    4.0         3.83         On Time            Traffic
# 3                   -1.0         2.76         On Time                NaN
# 4                    1.0         2.63         On Time            Traffic

# %%
# Remove the dash and convert to float
df9['delivery_time_minutes'] = df9['delivery_time_minutes'].astype(str).str.replace('-', '').astype(float)

# %%
df9.head()
# Out:
#      order_id  delivery_partner_id        promised_time          actual_time  \
# 0  1961864118                63230  2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  1549769649                14983  2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  9185164487                39859  2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  9644738826                61497  2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  5427684290                84315  2023-11-20 05:17:39  2023-11-20 05:18:39
#
#    delivery_time_minutes  distance_km delivery_status reasons_if_delayed
# 0                    5.0         0.96         On Time                NaN
# 1                    2.0         0.98         On Time            Traffic
# 2                    4.0         3.83         On Time            Traffic
# 3                    1.0         2.76         On Time                NaN
# 4                    1.0         2.63         On Time            Traffic

# %%
df9.head()
# Out:
#      order_id  delivery_partner_id        promised_time          actual_time  \
# 0  1961864118                63230  2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  1549769649                14983  2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  9185164487                39859  2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  9644738826                61497  2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  5427684290                84315  2023-11-20 05:17:39  2023-11-20 05:18:39
#
#    delivery_time_minutes  distance_km delivery_status reasons_if_delayed
# 0                    5.0         0.96         On Time                NaN
# 1                    2.0         0.98         On Time            Traffic
# 2                    4.0         3.83         On Time            Traffic
# 3                    1.0         2.76         On Time                NaN
# 4                    1.0         2.63         On Time            Traffic

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               5000 non-null   int64
#  1   delivery_partner_id    5000 non-null   int64
#  2   promised_time          5000 non-null   object
#  3   actual_time            5000 non-null   object
#  4   delivery_time_minutes  5000 non-null   float64
#  5   distance_km            5000 non-null   float64
#  6   delivery_status        5000 non-null   object
#  7   reasons_if_delayed     3098 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 312.6+ KB

# %%
df9.reasons_if_delayed.fillna('No Delay',inplace=True)
# Out:
# C:\Users\sarbj\AppData\Local\Temp\ipykernel_29112\325616241.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df9.reasons_if_delayed.fillna('No Delay',inplace=True)

# %%
df9.isnull().sum()
# Out:
# order_id                 0
# delivery_partner_id      0
# promised_time            0
# actual_time              0
# delivery_time_minutes    0
# distance_km              0
# delivery_status          0
# reasons_if_delayed       0
# dtype: int64

# %%
df9.to_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_delivery_performance_clean.csv",index=False)

# %%
df2.shape
# Out:
# (268, 10)

# %%
df3.shape
# Out:
# (18105, 4)

# %%
products=pd.merge(df2,df3,on='product_id',how='inner')

# %%
df2.head()
# Out:
#    product_id product_name             category                    brand  \
# 0      153019       Onions  Fruits & Vegetables               Aurora LLC
# 1       11422     Potatoes  Fruits & Vegetables           Ramaswamy-Tata
# 2      669378     Potatoes  Fruits & Vegetables          Chadha and Sons
# 3      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 4      890623       Onions  Fruits & Vegetables  Sangha, Nagar and Varty
#
#     price      mrp  margin_percentage  shelf_life_days  min_stock_level  \
# 0  947.95  1263.93               25.0                3               13
# 1  127.16   169.55               25.0                3               20
# 2  212.14   282.85               25.0                3               23
# 3  209.59   279.45               25.0                3               10
# 4  354.52   472.69               25.0                3               27
#
#    max_stock_level
# 0               88
# 1               65
# 2               70
# ...

# %%
products.tail()
# Out:
#        product_id product_name  category       brand   price      mrp  \
# 18100      114414     Vitamins  Pharmacy  Kara-Golla  832.06  1040.07
# 18101      114414     Vitamins  Pharmacy  Kara-Golla  832.06  1040.07
# 18102      114414     Vitamins  Pharmacy  Kara-Golla  832.06  1040.07
# 18103      114414     Vitamins  Pharmacy  Kara-Golla  832.06  1040.07
# 18104      114414     Vitamins  Pharmacy  Kara-Golla  832.06  1040.07
#
#        margin_percentage  shelf_life_days  min_stock_level  max_stock_level  \
# 18100               20.0              365               26               66
# 18101               20.0              365               26               66
# 18102               20.0              365               26               66
# 18103               20.0              365               26               66
# 18104               20.0              365               26               66
#
#          date  stock_received  damaged_stock
# ...

# %%
products.iloc[250:284]
# Out:
#      product_id product_name             category                    brand  \
# 250      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 251      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 252      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 253      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 254      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 255      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 256      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 257      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 258      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 259      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 260      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# ...

# %%
products.category.value_counts()
# Out:
# category
# Dairy & Breakfast        2059
# Snacks & Munchies        1890
# Fruits & Vegetables      1877
# Grocery & Staples        1850
# Pharmacy                 1759
# Pet Care                 1673
# Household Care           1658
# Personal Care            1566
# Cold Drinks & Juices     1527
# Instant & Frozen Food    1402
# Baby Care                 844
# Name: count, dtype: int64

# %%
products.to_csv("C:\\Users\\sarbj\\Downloads\\blink it data\\blinkit_products_inventory_clean.csv",index=False)
